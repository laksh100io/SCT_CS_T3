# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 56.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 57.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.1 MB/s eta 0:00:00
# ...

# %%
# -*- coding: utf-8 -*-
"""Welcome To Colab

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/notebooks/intro.ipynb
"""

import streamlit as st
import re

# Function to check password strength
def check_password_strength(password):
    strength = 0
    criteria = {
        "Length (>= 8 chars)": len(password) >= 8,
        "Contains uppercase": re.search(r"[A-Z]", password) is not None,
        "Contains lowercase": re.search(r"[a-z]", password) is not None,
        "Contains digit": re.search(r"[0-9]", password) is not None,
        "Contains special char": re.search(r"[!@#$%^&*(),.?\":{}|<>]", password) is not None
    }

    for passed in criteria.values():
        if passed:
            strength += 1

    if strength <= 2:
        label = "❌ Weak"
        color = "red"
    elif strength == 3 or strength == 4:
        label = "⚠️ Moderate"
        color = "orange"
    else:
        label = "✅ Strong"
        color = "green"

    return label, color, criteria

# --- Streamlit UI ---
st.set_page_config(page_title="Password Strength Checker", page_icon="🔐")

st.title("🔐 Password Strength Checker")
st.write("Enter a password to check its strength based on common criteria.")

# Password input field
password = st.text_input("Enter your password", type="password")

if password:
    label, color, details = check_password_strength(password)

    # Strength result
    st.markdown(f"### Strength: <span style='color:{color}'>{label}</span>", unsafe_allow_html=True)

    # Detailed breakdown
    st.markdown("#### Criteria:")
    for rule, passed in details.items():
        icon = "✅" if passed else "❌"
        st.markdown(f"- {icon} {rule}")
# Out:
# 2025-08-17 15:12:59.869 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 15:12:59.871 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 15:12:59.976
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2025-08-17 15:12:59.979 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 15:12:59.982 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-17 15:12:59.983 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
